# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **JUSTIN SOREL INTWARI**
# Data Scientist

# %% [markdown]
# *I would like to be a data scientist for their impact and use in businesses and healthcare oraganizations. The outcome of a data science project is as thrilling as useful to each and every organization.*

# %% [markdown]
# ### My Code is going to calculate the percentage of a given number

# %%
percent = 12/ 58 * 100

print("Percentage of 12 out of 58: ",percent)
# Out:
# Percentage of 12 out of 58:  20.689655172413794

# %% [markdown]
# #### The blocked quotes!
# - Read books.
#
# - Practice everyday.
#
# #### Numbered list
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item
#
# #### Horizontal rule
# The Stranger and the old lady.
#
# ---
#
# The story starts with the a stranger in paris wondering around a ....
